# %%
# %%bash
#
# [ -s ./requirements_conda.txt ] && conda install --yes --file ./requirements_conda.txt
#
# [ -s ./requirements.txt ] && pip install -r ./requirements.txt
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda:
#
# The following packages will be UPDATED:
#
#     matplotlib:   2.0.2-np111py35_0  --> 2.0.2-np113py35_0
#     mkl:          11.3.3-0           --> 2017.0.1-0
#     numpy:        1.11.2-py35_0      --> 1.13.0-py35_0
#     pandas:       0.19.2-np111py35_1 --> 0.20.2-np113py35_0
#     scikit-learn: 0.18.1-np111py35_0 --> 0.18.1-np113py35_1
#     scipy:        0.18.1-np111py35_0 --> 0.19.0-np113py35_0
#
# mkl-2017.0.1-0 100% |###############################| Time: 0:00:01  70.36 MB/s
# numpy-1.13.0-p 100% |###############################| Time: 0:00:00  53.31 MB/s
# scipy-0.19.0-n 100% |###############################| Time: 0:00:00  54.44 MB/s
# pandas-0.20.2- 100% |###############################| Time: 0:00:00  54.47 MB/s
# scikit-learn-0 100% |###############################| Time: 0:00:00  49.07 MB/s
# matplotlib-2.0 100% |###############################| Time: 0:00:00  54.95 MB/s
